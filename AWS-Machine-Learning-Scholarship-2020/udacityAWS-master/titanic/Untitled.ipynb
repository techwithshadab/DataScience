# %% [markdown]
# # Titanic Data

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
print(titanic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
# Survived                   887 non-null int64
# Pclass                     887 non-null int64
# Name                       887 non-null object
# Sex                        887 non-null object
# Age                        887 non-null float64
# Siblings/Spouses Aboard    887 non-null int64
# Parents/Children Aboard    887 non-null int64
# Fare                       887 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB
# None

# %%
print(dir(titanic))
# Out:
# ['Age', 'Fare', 'Name', 'Pclass', 'Sex', 'Survived', 'T', '_AXIS_ALIASES', '_AXIS_IALIASES', '_AXIS_LEN', '_AXIS_NAMES', '_AXIS_NUMBERS', '_AXIS_ORDERS', '_AXIS_REVERSED', '__abs__', '__add__', '__and__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__',
# ...

# %%
print(len(titanic))
print(titanic.iteritems)
# Out:
# 887
# <bound method DataFrame.iteritems of      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
# ...

# %%
print(titanic._repr_html_)
# Out:
# <bound method DataFrame._repr_html_ of      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
# ...

# %%
print(titanic.index)
# Out:
# RangeIndex(start=0, stop=887, step=1)

# %%
for index in range(len(titanic)):
    print(titanic.values[index])
# Out:
# [0 3 'Mr. Owen Harris Braund' 'male' 22.0 1 0 7.25]
# [1 1 'Mrs. John Bradley (Florence Briggs Thayer) Cumings' 'female' 38.0 1
#  0 71.2833]
# [1 3 'Miss. Laina Heikkinen' 'female' 26.0 0 0 7.925]
# [1 1 'Mrs. Jacques Heath (Lily May Peel) Futrelle' 'female' 35.0 1 0 53.1]
# [0 3 'Mr. William Henry Allen' 'male' 35.0 0 0 8.05]
# [0 3 'Mr. James Moran' 'male' 27.0 0 0 8.4583]
# [0 1 'Mr. Timothy J McCarthy' 'male' 54.0 0 0 51.8625]
# [0 3 'Master. Gosta Leonard Palsson' 'male' 2.0 3 1 21.075]
# [1 3 'Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson' 'female' 27.0 0 2
#  11.1333]
# [1 2 'Mrs. Nicholas (Adele Achem) Nasser' 'female' 14.0 1 0 30.0708]
# [1 3 'Miss. Marguerite Rut Sandstrom' 'female' 4.0 1 1 16.7]
# [1 1 'Miss. Elizabeth Bonnell' 'female' 58.0 0 0 26.55]
# [0 3 'Mr. William Henry Saundercock' 'male' 20.0 0 0 8.05]
# [0 3 'Mr. Anders Johan Andersson' 'male' 39.0 1 5 31.275]
# [0 3 'Miss. Hulda Amanda Adolfina Vestrom' 'female' 14.0 0 0 7.8542]
# ...

# %%
print(titanic.plot())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(titanic.get_values())
# Out:
# [[0 3 'Mr. Owen Harris Braund' ... 1 0 7.25]
#  [1 1 'Mrs. John Bradley (Florence Briggs Thayer) Cumings' ... 1 0
#   71.2833]
#  [1 3 'Miss. Laina Heikkinen' ... 0 0 7.925]
#  ...
#  [0 3 'Miss. Catherine Helen Johnston' ... 1 2 23.45]
#  [1 1 'Mr. Karl Howell Behr' ... 0 0 30.0]
#  [0 3 'Mr. Patrick Dooley' ... 0 0 7.75]]
# C:\Users\pielo2\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
#   """Entry point for launching an IPython kernel.

# %%
print(titanic.values)
# Out:
# [[0 3 'Mr. Owen Harris Braund' ... 1 0 7.25]
#  [1 1 'Mrs. John Bradley (Florence Briggs Thayer) Cumings' ... 1 0
#   71.2833]
#  [1 3 'Miss. Laina Heikkinen' ... 0 0 7.925]
#  ...
#  [0 3 'Miss. Catherine Helen Johnston' ... 1 2 23.45]
#  [1 1 'Mr. Karl Howell Behr' ... 0 0 30.0]
#  [0 3 'Mr. Patrick Dooley' ... 0 0 7.75]]

# %%
print(titanic["Age"] > 35)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# Name: Age, Length: 887, dtype: bool

# %%
above_35 = titanic[titanic["Age"] > 35]
above_35.head()

# %%
above_35.shape
# Out:
# (262, 8)

# %%
class_23 = titanic[(titanic["Pclass"] == 2) | (titanic["Pclass"] == 3)]
class_23.head(30)
# Out:
#     Survived  Pclass                                               Name  \
# 0          0       3                             Mr. Owen Harris Braund
# 2          1       3                              Miss. Laina Heikkinen
# 4          0       3                            Mr. William Henry Allen
# 5          0       3                                    Mr. James Moran
# 7          0       3                      Master. Gosta Leonard Palsson
# 8          1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9          1       2                 Mrs. Nicholas (Adele Achem) Nasser
# 10         1       3                     Miss. Marguerite Rut Sandstrom
# 12         0       3                      Mr. William Henry Saundercock
# 13         0       3                         Mr. Anders Johan Andersson
# 14         0       3                Miss. Hulda Amanda Adolfina Vestrom
# 15         1       2                     Mrs. (Mary D Kingcome) Hewlett
# ...

# %%
age_no_na = titanic[titanic["Age"].notna()]
noage = len(age_no_na)

# %%
print(noage)
# Out:
# 887

# %%
row_col = titanic.iloc[9:25, 2:5]

# %%
print(row_col)
# Out:
#                                                  Name     Sex   Age
# 9                  Mrs. Nicholas (Adele Achem) Nasser  female  14.0
# 10                     Miss. Marguerite Rut Sandstrom  female   4.0
# 11                            Miss. Elizabeth Bonnell  female  58.0
# 12                      Mr. William Henry Saundercock    male  20.0
# 13                         Mr. Anders Johan Andersson    male  39.0
# 14                Miss. Hulda Amanda Adolfina Vestrom  female  14.0
# 15                     Mrs. (Mary D Kingcome) Hewlett  female  55.0
# 16                                Master. Eugene Rice    male   2.0
# 17                        Mr. Charles Eugene Williams    male  23.0
# 18  Mrs. Julius (Emelia Maria Vandemoortele) Vande...  female  31.0
# 19                             Mrs. Fatima Masselmani  female  22.0
# 20                                Mr. Joseph J Fynney    male  35.0
# 21                               Mr. Lawrence Beesley    male  34.0
# ...

# %%
adult_names = titanic.loc[titanic["Age"] > 35, "Name"]
print(adult_names)
print(len(adult_names))
# Out:
# 1      Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 6                                 Mr. Timothy J McCarthy
# 11                               Miss. Elizabeth Bonnell
# 13                            Mr. Anders Johan Andersson
# 15                        Mrs. (Mary D Kingcome) Hewlett
#                              ...
# 861                              Mrs. (Karolina) Bystrom
# 867      Mrs. Richard Leonard (Sallie Monypeny) Beckwith
# 869                           Mr. Victor Vander Cruyssen
# 875         Mrs. Thomas Jr (Lily Alexenia Wilson) Potter
# 881                  Mrs. William (Margaret Norton) Rice
# Name: Name, Length: 262, dtype: object
# 262

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic["Fare"].plot()

# %%
titanic["Siblings/Spouses Aboard"].plot()

# %%
titanic.plot.scatter(x="Age",y="Fare", alpha=0.5)

# %%
titanic.plot.box()

# %%
fig, axs = plt.subplots(figsize=(12, 4));

# %%
row_col.shape
fig = row_col.plot.area(figsize=(50, 10), subplots=True)

# %%
fig.savefig("matplottester.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-41e300b828c2> in <module>
# ----> 1 fig.savefig("matplottester.png")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'savefig'

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import plot_roc_curve
from sklearn.datasets import load_wine

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
svc = SVC(random_state=42)
svc.fit(X_train, y_train)

svc_disp = plot_roc_curve(svc, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-75-91d4ce6a22ad> in <module>
#       1 from sklearn.model_selection import train_test_split
#       2 from sklearn.svm import SVC
# ----> 3 from sklearn.metrics import plot_roc_curve
#       4 from sklearn.datasets import load_wine
#       5
#
# ImportError: cannot import name 'plot_roc_curve' from 'sklearn.metrics' (C:\Users\pielo2\Anaconda3\lib\site-packages\sklearn\metrics\__init__.py)
