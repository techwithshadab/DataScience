# %% [markdown]
# # Optimizing Code: Holiday Gifts

# %%
import time
import numpy as np

# %%
with open('census-income.data') as f:
    gift_costs = f.read().split('\n')
    
gift_costs = np.array(gift_costs).astype(int)  # convert string to int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-b977a5c2d527> in <module>
#       2     gift_costs = f.read().split('\n')
#       3
# ----> 4 gift_costs = np.array(gift_costs).astype(int)  # convert string to int
#
# ValueError: invalid literal for int() with base 10: '39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K'

# %%
start = time.time()

total_price = 0
for cost in gift_costs:
    if cost < 25:
        total_price += cost * 1.08  # add cost after tax

print(total_price)
print('Duration: {} seconds'.format(time.time() - start))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-63e363c3a90c> in <module>
#       3 total_price = 0
#       4 for cost in gift_costs:
# ----> 5     if cost < 25:
#       6         total_price += cost * 1.08  # add cost after tax
#       7
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
start = time.time()

total_price = (gift_costs[gift_costs < 25]).sum() * 1.08
print(total_price)

print('Duration: {} seconds'.format(time.time() - start))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b5ed421181f2> in <module>
#       1 start = time.time()
#       2
# ----> 3 total_price = (gift_costs[gift_costs < 25]).sum() * 1.08
#       4 print(total_price)
#       5
#
# TypeError: '<' not supported between instances of 'list' and 'int'
