# %% [markdown]
# ## Creating Data Visualizations

# %% [markdown]
# ### Plotting systems in R
# 1. Base- basic data visualization capacity
# 2. Lattice- based on trellis graphics, originally developed for statistical programming languages
# 3. ggplot2- based on The Grammar of Graphics(a thesis on statistical graphics)

# %%
# Set the working directory
setwd("C:/DataScience")

# %%
# Read a tab-delimited data file
cars <- read.csv("Cars.csv")

# %%
# Peek at the data
head(cars)
# Out:
#   Name           Transmission Cylinders Fuel.Economy
# 1 Mazda RX4      Manual       6         21.0
# 2 Mazda RX4 Wag  Manual       6         21.0
# 3 Datsun 710     Manual       4         22.8
# 4 Hornet 4 Drive Automatic    6         21.4
# 5 Hornet Sport   Automatic    8         18.7
# 6 Valiant        Automatic    6         18.1

# %%
# Load the ggplot2 library
library(ggplot2)

# %%
# Create a frequency bar chart
ggplot(data=cars, aes(x=Transmission))+geom_bar()+ggtitle("Count of cars by Transmission type")+xlab("Transmission Type")+ylab("Count of Cars")
# Out:
# plot without title

# %%
# Create a histogram
ggplot(data=cars, aes(x=Fuel.Economy))+geom_histogram(bins=10)+ggtitle("Distribution of Fuel Economy")+xlab("Fuel Economy (mpg)")+ylab("Count of Cars")
# Out:
# plot without title

# %%
# Create a density plot
ggplot(data=cars, aes(x=Fuel.Economy))+geom_density()+ggtitle("Distribution of Fuel Economy")+xlab("Fuel Economy (mpg)")+ylab("Density")
# Out:
# plot without title

# %%
# Create a scatter plot
ggplot(data=cars, aes(x=Cylinders, y=Fuel.Economy))+geom_point()+ggtitle("Fuel Economy by Cylinders")+ylab("Fuel Economy (mpg)")+xlab("Number of Cylinders")
# Out:
# plot without title
